# %%
#Encapsulation- It means restricting direct access to some of the object's components, which is key for data hiding and protection.
#public,protected,private variable.
#using property(fget,fset,fdel,"doc")
#__str__,__repr__,__add__,__call__
# Polymorphism

# class employee:
#     def __init__(self,name,salary):
#         self.name = name
#         self.__salary = salary

# e = employee("Janani", 50000)
# print(e.name)
# print(e.__salary)

# #Public variable - access inside and outside, anywhere in the class
# class employee:
#     def __init__(self,name):
#         self.name = name
#     def display_info(self):
#         print(self.name)

# e = employee("Janani")
# e.display_info()

# #protected variables - not private, accessed only within the class and its subclass. single underscore.
# class employee:
#     def __init__(self,name,age):
#         self.name = name
#         self._age = age

# # class subemployee(employee):
# #     def show_age(self):
#         print(f"Age: {self._age}")

# e = subemployee("Janani",24)
# print(f"Name: {e.name}")
# e.show_age()

# #private variable - cannot access directly outside the class. double underscore. accessed within the class using a public method.
# class employee:
#     def __init__(self,name,age):
#         self.name = name
#         self.__age = age

#     def show_age(self):
#         print(f"Age: {self.__age}")

# e = subemployee("Janani",24)
# print(f"Name: {e.name}")
# e.show_age()

# #using all of these= bank example
# class BankAccount:
#     def __init__(self):
#         self.balance = 1000

#     def _show_balance(self): #protected method
#         print(f"Balance: {self.balance}")

#     def __update_balance(self,amount):#private method
#         self.balance += amount

#     def deposit(self,amount):
#         if amount > 0:
#             self.__update_balance(amount) #accessing private
#             self._show_balance()#accessing protected
#         else:
#             print("Invalid deposit")

# account = BankAccount()
# account._show_balance()
# account.deposit(500)

# #getter and setter method - used to access and modify private attributes safely. Read data using a getter method.
# # Update data using a setter method with optional validation or restrictions
# class employee:
#     def __init__(self):
#         self.__salary = 50000

#     def get_salary(self):
#         print(f"Salary: {self.__salary}")

#     def set_salary(self,amount):
#         if amount > 0:
#             self.__salary = amount
#         else:
#             print("Invalid salary!")

# e = employee()
# e.get_salary()
# e.set_salary(60000)
# e.get_salary()

# using __repr__ - returns a detailed description and __str__ - returns a simpler description method - 
# both return string representations of the object(string that shows information about the object)
# .__repr__() provides the official string representation of an object, aimed at the programmer.
# .__str__() provides the informal string representation of an object, aimed at the user. using print() it return string.
#to access without calling method name outside the class
# class Employee:
#     def __init__(self, name, salary):
#         self.name = name
#         self.salary = salary

#     def __repr__(self):
#         return f"Employee: {self.name}, Salary: {self.salary}"

# emp1 = Employee("Janani", 7000)
# emp1  

# class Person:
#     def __init__(self, name):
#         self.name = name
    
#     def __str__(self):
#         return f"Name: {self.name}"
    
#     def __repr__(self):
#         return f"Person(name='{self.name}')"
# p=Person("revathi")
# print(p)

# #to access private variable without calling methods outside the class
# class person:
#     def __init__(self,name):
#         self.__name = name
#     def get_name(self):
#         return f"Name: {self.__name}"
#     def set_name(self,name):
#         self.__name = name
#     def del_name(self):
#         del self.__name
#     name = property(get_name,set_name,del_name,"The name of the employee")
    
# p = person("Janani")
# # print(p.name)
# p.name ="Angel"
# print(p.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 49
#      46     def show_age(self):
#      47         print(f"Age: {self.__age}")
# ---> 49 e = subemployee("Janani",24)
#      50 print(f"Name: {e.name}")
#      51 e.show_age()
#
# NameError: name 'subemployee' is not defined

# %%
#polymorphism - poly(many) and morphism(forms). if objects from different classes share the same method name they can be treated polymorphically, 
# even without explicit inheritance. two types=method overloading and method overriding
#Method Overloading (Same Method Name, Different Parameters)
def add(a,b):
    d = a+b
    return d

def add(a,b,c): # this will work cause it overwrite the function. if we give add(3,4) it will throw error.
    d = a+b+c
    return d

add(3,4,5)

#Method Overriding (Same Method Name in Child Class)
# Method overriding means redefining a method from the parent class in the child class to give it a new behavior.
# Polymorphism with Inheritance (Method Overriding)-Child classes can inherit methods from a parent class and 
# then redefine or "override" those methods to provide their own specific implementation, while still sharing the same method name.
class animal:
    def speak(self):
        print("Animal speaks")

class dog(animal):
    def speak(self):
        print("Dog barks")

d = dog()
d.speak()
# Out:
# Dog barks
