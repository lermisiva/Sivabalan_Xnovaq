# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
os.chdir ('C:\\Users\\XNovaQ.23\\Documents\\Git JN\\Sivabalan_Xnovaq\\Ai model class adn example\\Dec 2025 Day 3')

# %%
pwd
# Out:
# 'C:\\Users\\XNovaQ.23\\Documents\\Git JN\\Sivabalan_Xnovaq\\Ai model class adn example\\Dec 2025 Day 3'

# %%
df = pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
#split x 
x = df.iloc[:,:-1]
print(x)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
#split y
y = df.iloc[:,1:]
print (y)
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
#show x and y in the for how line go
plt.plot(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
print ('X Shape-',x.shape)
print ('Y Shape-', y.shape)
print ('X_Train Shape-',x_train.shape)
print ('Y_Train Shape-',y_train.shape)
print ('X_Test Shape-',x_test.shape)
print ('Y_Test Shape-',y_test.shape)
# Out:
# X Shape- (30, 1)
# Y Shape- (30, 1)
# X_Train Shape- (24, 1)
# Y_Train Shape- (24, 1)
# X_Test Shape- (6, 1)
# Y_Test Shape- (6, 1)

# %%
print (x_test)
# Out:
#     YearsExperience
# 20              6.8
# 24              8.7
# 19              6.0
# 0               1.1
# 1               1.3
# 21              7.1

# %%
print(x_train)
# Out:
#     YearsExperience
# 4               2.2
# 6               3.0
# 23              8.2
# 2               1.5
# 13              4.1
# 12              4.0
# 25              9.0
# 5               2.9
# 22              7.9
# 9               3.7
# 27              9.6
# 17              5.3
# 16              5.1
# 3               2.0
# 26              9.5
# 18              5.9
# 8               3.2
# 11              4.0
# 15              4.9
# 28             10.3
# 14              4.5
# 7               3.2
# 29             10.5
# 10              3.9

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
print (lr)
# Out:
# LinearRegression()

# %%
y_pred= lr.predict(x_test)
print (y_pred)
# Out:
# [[ 88927.7155185 ]
#  [107114.49217493]
#  [ 81270.12534737]
#  [ 34367.38554922]
#  [ 36281.783092  ]
#  [ 91799.31183268]]

# %%
print (x_test)
# Out:
#     YearsExperience
# 20              6.8
# 24              8.7
# 19              6.0
# 0               1.1
# 1               1.3
# 21              7.1

# %%
#r2 score means accurarcy 
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9216736936585541

# %%
# to reset the index
x_test=x_test.reset_index()
print (x_test)
# Out:
#    index  YearsExperience
# 0     16              5.1
# 1     14              4.5
# 2      9              3.7
# 3     24              8.7
# 4     29             10.5
# 5     10              3.9

# %%
#drop the old index num column
x_test=x_test.drop('index',axis =1)
print (x_test)
# Out:
#    YearsExperience
# 0              5.1
# 1              4.5
# 2              3.7
# 3              8.7
# 4             10.5
# 5              3.9

# %%
# same to y -text
y_test
# Out:
#     Salary
# 16   66029
# 14   61111
# 9    57189
# 24  109431
# 29  121872
# 10   63218

# %%
# reset index of y
y_test=y_test.reset_index()
print (y_test)
# Out:
#    index  Salary
# 0     16   66029
# 1     14   61111
# 2      9   57189
# 3     24  109431
# 4     29  121872
# 5     10   63218

# %%
#drop the old index num column
y_test=y_test.drop('index',axis =1)
print (y_test)
# Out:
#    Salary
# 0   66029
# 1   61111
# 2   57189
# 3  109431
# 4  121872
# 5   63218

# %%
# default is array
y_pred
# Out:
# array([[ 74815.05730283],
#        [ 69136.43257065],
#        [ 61564.93292774],
#        [108886.8056959 ],
#        [125922.67989243],
#        [ 63457.80783847]])

# %%
# make this as a column 
y_pred = pd.DataFrame (y_pred,columns = ['Prediction'])
print (y_pred)
# Out:
#       Prediction
# 0   74815.057303
# 1   69136.432571
# 2   61564.932928
# 3  108886.805696
# 4  125922.679892
# 5   63457.807838

# %%
# Add the prediction column into the datset
y_test_pred = pd.concat ([x_test,y_test,y_pred],axis =1)
result['Difference'] = y_test['Salary']- y_pred['Prediction']
print (result)
# Out:
#    index  YearsExperience  Salary     Prediction   Difference
# 0      0              5.1   66029   74815.057303 -8786.057303
# 1      1              4.5   61111   69136.432571 -8025.432571
# 2      2              3.7   57189   61564.932928 -4375.932928
# 3      3              8.7  109431  108886.805696   544.194304
# 4      4             10.5  121872  125922.679892 -4050.679892
# 5      5              3.9   63218   63457.807838  -239.807838

# %%
# to check the accurarcy
from sklearn.metrics import r2_score
accuracy =r2_score(y_test,y_pred)
print (accuracy)
# Out:
# 0.9553223213582563

# %% [markdown]
# # after that i want to improve the accurarcy

# %%
#SO i want to find the # y= mx+c  m = coef_
print (lr.coef_)
# Out:
# [[9464.37455363]]

# %%
# c = intercept_
print (lr.intercept_)
# Out:
# [26546.74707931]

# %%
# y = mx+ c
2.2*9563.26912855+25004.63997761924
# Out:
# 46043.83206042924

# %%
print (y_test_pred)
# Out:
#    index  YearsExperience  Salary     Prediction
# 0      0              5.1   66029   74815.057303
# 1      1              4.5   61111   69136.432571
# 2      2              3.7   57189   61564.932928
# 3      3              8.7  109431  108886.805696
# 4      4             10.5  121872  125922.679892
# 5      5              3.9   63218   63457.807838

# %%
# final predict with the pattern with linear 
y_pred_final =lr.predict (x)
y_pred_final
# Out:
# array([[ 36957.5590883 ],
#        [ 38850.43399903],
#        [ 40743.30890976],
#        [ 45475.49618657],
#        [ 47368.3710973 ],
#        [ 53993.43328484],
#        [ 54939.8707402 ],
#        [ 56832.74565093],
#        [ 56832.74565093],
#        [ 61564.93292774],
#        [ 63457.80783847],
#        [ 64404.24529383],
#        [ 64404.24529383],
#        [ 65350.6827492 ],
#        [ 69136.43257065],
#        [ 72922.1823921 ],
#        [ 74815.05730283],
#        [ 76707.93221355],
#        [ 82386.55694573],
#        [ 83332.99440109],
#        [ 90904.494044  ],
#        [ 93743.80641009],
#        [101315.30605299],
#        [104154.61841908],
#        [108886.8056959 ],
#        [111726.11806198],
#        [116458.3053388 ],
#        [117404.74279416],
#        [124029.8049817 ],
#        [125922.67989243]])

# %%
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(df['Salary'],y_pred_final)
print (accuracy)
# Out:
# 0.9560036226134291

# %%
pd.DataFrame(lr.predict(x))
# Out:
#                 0
# 0    36957.559088
# 1    38850.433999
# 2    40743.308910
# 3    45475.496187
# 4    47368.371097
# 5    53993.433285
# 6    54939.870740
# 7    56832.745651
# 8    56832.745651
# 9    61564.932928
# 10   63457.807838
# 11   64404.245294
# 12   64404.245294
# 13   65350.682749
# 14   69136.432571
# 15   72922.182392
# 16   74815.057303
# 17   76707.932214
# 18   82386.556946
# 19   83332.994401
# 20   90904.494044
# 21   93743.806410
# 22  101315.306053
# 23  104154.618419
# 24  108886.805696
# 25  111726.118062
# 26  116458.305339
# 27  117404.742794
# 28  124029.804982
# 29  125922.679892

# %%
pd.DataFrame(lr.predict(x),columns= ['Salary Prediction'])
# Out:
#     Salary Prediction
# 0        36957.559088
# 1        38850.433999
# 2        40743.308910
# 3        45475.496187
# 4        47368.371097
# 5        53993.433285
# 6        54939.870740
# 7        56832.745651
# 8        56832.745651
# 9        61564.932928
# 10       63457.807838
# 11       64404.245294
# 12       64404.245294
# 13       65350.682749
# 14       69136.432571
# 15       72922.182392
# 16       74815.057303
# 17       76707.932214
# 18       82386.556946
# 19       83332.994401
# 20       90904.494044
# 21       93743.806410
# 22      101315.306053
# 23      104154.618419
# 24      108886.805696
# 25      111726.118062
# 26      116458.305339
# 27      117404.742794
# 28      124029.804982
# 29      125922.679892

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
y_pred_final = pd.DataFrame(lr.predict(x),columns= ['Salary Prediction'])
result = pd.concat([df,y_pred_final], axis =1)
result['Difference'] = df['Salary']-y_pred_final['Salary Prediction']
print (result)
result.to_excel("prediction_Simple Regression.xlsx")
# Out:
#     YearsExperience  Salary  Salary Prediction    Difference
# 0               1.1   39343       36957.559088   2385.440912
# 1               1.3   46205       38850.433999   7354.566001
# 2               1.5   37731       40743.308910  -3012.308910
# 3               2.0   43525       45475.496187  -1950.496187
# 4               2.2   39891       47368.371097  -7477.371097
# 5               2.9   56642       53993.433285   2648.566715
# 6               3.0   60150       54939.870740   5210.129260
# 7               3.2   54445       56832.745651  -2387.745651
# 8               3.2   64445       56832.745651   7612.254349
# 9               3.7   57189       61564.932928  -4375.932928
# 10              3.9   63218       63457.807838   -239.807838
# 11              4.0   55794       64404.245294  -8610.245294
# 12              4.0   56957       64404.245294  -7447.245294
# 13              4.1   57081       65350.682749  -8269.682749
# ...

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(df['Salary'],y_pred_final)
print (accuracy)
# Out:
# 0.9560036226134291

# %%
x_train
# Out:
#     YearsExperience
# 0               1.1
# 12              4.0
# 15              4.9
# 21              7.1
# 8               3.2
# 13              4.1
# 6               3.0
# 19              6.0
# 22              7.9
# 26              9.5
# 1               1.3
# 23              8.2
# 27              9.6
# 20              6.8
# 4               2.2
# 7               3.2
# 18              5.9
# 28             10.3
# 17              5.3
# 5               2.9
# 3               2.0
# 11              4.0
# 25              9.0
# 2               1.5

# %%
lr.predict ([[15]])
# Out:
# C:\Users\XNovaQ.23\Documents\Git JN\Sivabalan_Xnovaq\pyenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[168512.36538377]])

# %%
15*9563.26912855+25004.63997761924
# Out:
# 168453.67690586927

# %%
plt.plot (x,y) 
plt.show()

# %%
plt.plot (x,y) 
plt.plot (x,y_pred_final)
plt.show()

# %%
plt.scatter (x,y) 
plt.plot (x,y_pred_final, 'r')
plt.show()
