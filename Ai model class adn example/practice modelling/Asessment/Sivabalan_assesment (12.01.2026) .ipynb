# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir("C:\\Users\\XNovaQ.23\\Documents\\Git JN\\Sivabalan_Xnovaq\\Ai model class adn example\\practice modelling\\Asessment")

# %%
pwd
# Out:
# 'C:\\Users\\XNovaQ.23\\Documents\\Git JN\\Sivabalan_Xnovaq\\Ai model class adn example\\practice modelling\\Asessment'

# %%
df =pd.read_csv("Train.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300               LF         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
x = df.iloc[:,:11]
x
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300               LF         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
y = df.iloc[:,-1]
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
x.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
# x['Item_Weight']=x.fillna(x['Item_Weight'].groupby(['Item_Identifier']).mean())
# x.groupby(['Item_Weight']['Item_Identifier'])
# from sklearn.impute import SimpleImputer
# x['Item_Weight']=x.groupby('Item_Weight')[['Item_Identifier']]
# x['Item_Weight']
df['Item_Visibility'].mean()
# Out:
# np.float64(0.06613202877895107)

# %%
df['Item_Visibility'] = df['Item_Visibility'].replace(0,df['Item_Visibility'].mean())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300               LF         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.066132
# 4           NCD19        8.930          Low Fat         0.066132
# 5           FDP36       10.395          Regular         0.066132
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'] = df.groupby('Item_Identifier')['Item_Weight'].transform('first')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300               LF         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     4
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
result1 = df.groupby('Outlet_Type')['Outlet_Size'].first()
result1
# Out:
# Outlet_Type
# Grocery Store         Small
# Supermarket Type1    Medium
# Supermarket Type2    Medium
# Supermarket Type3    Medium
# Name: Outlet_Size, dtype: object

# %%
df['Outlet_Size'] = df.groupby('Outlet_Type')['Outlet_Size'].transform('first')

# %%
replace_values = {'lf': 'Low Fat','low fat': 'Low Fat', 'reg': 'Regular'}
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace(replace_values)

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  4
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
null_rows = df[df.isnull().any(axis=1)]
print("Rows with null values:\n", null_rows)
# Out:
# Rows with null values:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927            FDN52          NaN          Regular         0.130933
# 1922           FDK57          NaN          Low Fat         0.079904
# 4187           FDE52          NaN          Regular         0.029742
# 5022           FDQ60          NaN          Regular         0.191501
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927   Frozen Foods   86.9198            OUT027                       1985
# 1922   Snack Foods  120.0440            OUT027                       1985
# 4187         Dairy   88.9514            OUT027                       1985
# 5022  Baking Goods  121.2098            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927       Medium               Tier 3  Supermarket Type3          1569.9564
# 1922      Medium               Tier 3  Supermarket Type3          4434.2280
# ...

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df['Separate_Identifier'] = df['Item_Identifier'].str[:2]

# %%
col_data = df.pop('Separate_Identifier')
df.insert(1, 'Separate_Identifier', col_data)

# %%
df['Separate_Identifier'].unique()
# Out:
# array(['FD', 'DR', 'NC'], dtype=object)

# %%
df['Separate_Outlet'] = df['Outlet_Identifier'].str[:3]

# %%
cols_data = df.pop('Separate_Outlet')
df.insert(8, 'Separate_Outlet', cols_data)

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
columns = ['Separate_Identifier','Item_Fat_Content','Item_Type','Separate_Outlet','Outlet_Size','Outlet_Location_Type','Outlet_Type']
from sklearn.preprocessing import LabelEncoder
for col in columns:
    df[col] = LabelEncoder().fit_transform(df[col])

# %%
y = df.iloc[:,-1:].values
y
# Out:
# array([[3735.138 ],
#        [ 443.4228],
#        [2097.27  ],
#        ...,
#        [1193.1136],
#        [1845.5976],
#        [ 765.67  ]], shape=(8523, 1))

# %%
x = df.iloc[:,:-1]
numeric_cols = x.select_dtypes(include=['int64', 'float64']).columns.tolist()
x = x[numeric_cols].values
x
# Out:
# array([[ 1.  ,  9.3 ,  0.  , ...,  0.  ,  0.  ,  1.  ],
#        [ 0.  ,  5.92,  2.  , ...,  0.  ,  2.  ,  2.  ],
#        [ 1.  , 17.5 ,  1.  , ...,  0.  ,  0.  ,  1.  ],
#        ...,
#        [ 2.  , 10.6 ,  1.  , ...,  0.  ,  1.  ,  1.  ],
#        [ 1.  ,  7.21,  2.  , ...,  0.  ,  2.  ,  2.  ],
#        [ 0.  , 14.8 ,  1.  , ...,  0.  ,  0.  ,  1.  ]], shape=(8523, 11))

# %%
print(x.shape)
print(y.shape)
# Out:
# (8523, 11)
# (8523, 1)

# %%
# Multiple linear regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6818, 11)
# (1705, 11)
# (6818, 1)
# (1705, 1)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
print (y_pred)
# Out:
# [[1546.01715977]
#  [ 859.41304603]
#  [ 848.64369861]
#  ...
#  [1008.78064384]
#  [1019.71446705]
#  [1703.40067341]]

# %%
result = pd.concat([pd.DataFrame(y_pred, columns = ['Prediction']),
                    pd.DataFrame(y_test,columns = ['Y_Test'])], axis =1)
result['Difference']= y_test -y_pred
print (result)
# Out:
#        Prediction     Y_Test   Difference
# 0     1546.017160  1743.0644   197.047240
# 1      859.413046   356.8688  -502.544246
# 2      848.643699   377.5086  -471.135099
# 3     4048.416501  5778.4782  1730.061699
# 4     3097.752070  2356.9320  -740.820070
# ...           ...        ...          ...
# 1700  2212.363823  3004.0896   791.725777
# 1701  2527.920195   890.8404 -1637.079795
# 1702  1008.780644   629.1810  -379.599644
# 1703  1019.714467   253.0040  -766.710467
# 1704  1703.400673   976.7286  -726.672073
#
# [1705 rows x 3 columns]

# %%
print (model.coef_)
print (model.intercept_)
# Out:
# [[ 2.01010416e+00 -1.77487501e+00  5.28445373e+01 -4.18545789e+02
#    3.58584077e-01  1.55883226e+01 -1.13686838e-13 -2.51469537e+01
#   -1.63108229e+03 -7.08338542e+01  4.66936782e+02]]
# [49929.30242272]

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test, y_pred)
print (accuracy)
# Out:
# 0.557371882115236

# %%
# Random forest
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100)
rf.fit (x,y)
# Out:
# C:\Users\XNovaQ.23\Documents\Git JN\Sivabalan_Xnovaq\pyenv\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = rf.predict(x)
print (y_pred)
# Out:
# [4562.833928  591.736408 2192.159816 ... 1232.255982 1805.662916
#   971.448806]

# %%
accuracy = r2_score(y,y_pred)
print (accuracy)
# Out:
# 0.9376014279228697
