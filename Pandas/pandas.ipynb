# %% [markdown]
# # Upload as a csv file

# %%
import pandas as pd
mydata = {'id':[1,2,3], 'name' :['Siva','dan','surya'],
         'job':['qa','qa','qa']} 
var = pd.DataFrame(mydata)
print(var)
var.to_csv('sample.csv', index=False)
# Out:
#    id   name job
# 0   1   Siva  qa
# 1   2    dan  qa
# 2   3  surya  qa

# %% [markdown]
# # Excel read

# %%
import pandas as pd
dummy = pd.read_excel("C:\\Users\\XNovaQ.23\\Downloads\\sample_50_members.xls")
print(dummy)
# Out:
#              Name    Phone Number    Country       City  Gender
# 0       Sneha Das  +91-6309447570        USA    Toronto  Female
# 1     Meera Reddy  +91-7301980383     Canada     Mumbai  Female
# 2    Anjali Patel  +91-8028657969  Australia  Hyderabad    Male
# 3    Snehal Yadav  +91-9210108202        USA    Chennai  Female
# 4    Ishaan Reddy  +91-8853253779        USA     Mumbai    Male
# 5   Lalitha Kumar  +91-6077357236        USA  Bangalore  Female
# 6     Varun Kumar  +91-9178091166  Australia    Toronto  Female
# 7     Manish Bose  +91-8221613091      India     Sydney    Male
# 8       Varun Das  +91-8701256350        USA     Sydney    Male
# 9     Simran Nair  +91-8436313419         UK      Delhi    Male
# 10      Raj Gupta  +91-8048111206     Canada    Toronto    Male
# 11   Vikram Reddy  +91-8588693307  Australia  Melbourne  Female
# 12    Simran Bose  +91-7501291061     Canada    Chennai  Female
# 13      Kiran Das  +91-6845499164  Australia     London  Female
# ...

# %% [markdown]
# # Convert to csv

# %%
# !pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 259.2 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/250.9 kB 409.6 kB/s eta 0:00:01
#    ----------------------------------- ---- 225.3/250.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import panda as pd
